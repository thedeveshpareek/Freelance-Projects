# %%
# !pip install youtube-search-python
# !pip install --upgrade google-api-python-client
# !pip install --upgrade google-auth google-auth-oauthlib google-auth-httplib2
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %% [markdown]
# ## **Importing the Necessary Libraries**
#
#
#
# ---

# %%
import argparse
import csv
import heapq
import re
import sys
import urllib.parse as p
from youtubesearchpython import *
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import json
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # 1) Connect to the Youtube API using a Python client
# ### a) Create a YouTube API key

# %%
DEVELOPER_KEY = 'AIzaSyCB8qrDk6ZI31svAOCJXoHzvtcUvUj1o-Y'
YOUTUBE_API_SERVICE_NAME = 'youtube'
YOUTUBE_API_VERSION = 'v3'
videos = []
channels = []
video_ids = []
descriptions = []
channel_title = []
video_title = []
channel_id = []
views_list = []
likes_list = []
comments_list = []
id_list = []
title_list = []
likess_list = []
viewss_list = []
commentss_list = []

# %% [markdown]
# # b) Install the Google API python **client**

# %%
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION,
    developerKey=DEVELOPER_KEY)

# %% [markdown]
# # 2) Search and extract the **data** from the Youtube API
# ---

# %% [markdown]
# ### a) Search videos related to the query string “avatar movie”
# (For this part, choose/search one video of your choice and perform data
# collection steps on that specific video )
# Output expected : ID, Snippet, Channel ID, Video Description, Channel Title,
# Video Title

# %%
def youtube_search(options):


  # Call the search.list method to retrieve results matching the specified
  # query term.
  search_response = youtube.search().list(
    q=options.q,
    part='id,snippet',
    maxResults=options.max_results
  ).execute()


  # Add each result to the appropriate list, and then display the lists of
  # matching videos, channels, and playlists.
  for search_result in search_response.get('items', []):
    print(search_result['snippet']['channelId'])
    channel_id.append(search_result['snippet']['channelId'])
    if search_result['id']['kind'] == 'youtube#video':
      videos.append('%s (%s)' % (search_result['snippet']['title'],
                                 search_result['id']['videoId']))

    if search_result['id']['kind'] == 'youtube#video':
      channels.append('%s (%s)' % (search_result['snippet']['title'],
                                   search_result['snippet']['channelId']))


  print('Videos:\n', '\n'.join(videos), '\n')
  print('Channels:\n', '\n'.join(channels), '\n')




args = argparse.Namespace(max_results=50, q='Avatar movie')
try:
  youtube_search(args)
except HttpError as e:
  print('An HTTP error %d occurred:\n%s' % (e.resp.status, e.content))

allSearch = CustomSearch('Avatar', VideoSortOrder.uploadDate, limit=50)


print(allSearch.result())
result = allSearch.result()
#print all the keys of the result
print(result['result'][0].keys())
#append id to list id
for i in result['result']:
  i = json.dumps(i)
  print(i)
  i = json.loads(str(i))

  video_ids.append(i["id"])
  # description.append(i["description"])
  channel_title.append(i["channel"]["name"])
  video_title.append(i["title"])
  #get likes


#print id


limit = 500
for video_id in video_ids:
  try:
      payload = {'limit': limit}
      url = 'https://www.youtube.com/watch?v=' + video_id
      response = requests.get(url, params=payload)
      print(video_id)
      if response.status_code == 200:
          soup = BeautifulSoup(response.text, 'html.parser')
          description = soup.find('meta', attrs={'name': 'description'})
          print(description)

          #remove the meta tag from description
          description = str(description).replace('<meta content="', '')
          descriptions.append(description)
          #get likes
          likes = soup.find('yt-formatted-string', attrs={'name':'like-count'})
      #get comments
  except Exception as e:
    print(e)
    pass


# youtube = youtube_authenticate()
# Out:
# UCiN-1mdDS4H9QJN_1-5PRdg
# UCF1JIbMUs6uqoZEY1Haw0GQ
# UCRyGpVmsGSpbH2N9n5xx-AA
# UC2MR8wuMwaS3hN9leOXl_Dg
# UClEiTEnlbgmZBczuWctSNDA
# UCgjxQJ6TlKqhHax8742ZMdA
# UC6LDwTYRfjQwkakw5R95OyA
# UCsuOs8KvVuqvQv-pV01fCyg
# UC3yjWvF_XbMybc4NJVJjUsQ
# UCXSi7KDGFmsD5iL_Di_hB0A
# UC4qGmRZ7aLOLfVsSdj5Se2A
# UCgjxQJ6TlKqhHax8742ZMdA
# UCgjxQJ6TlKqhHax8742ZMdA
# UC9v4vMSdJRND1YGp7-S8dRQ
# UCWaFpmW9prSna3sbJq5V6wg
# UCzBay5naMlbKZicNqYmAQdQ
# UC1AJxP0vC_yqPUtr2MQttRQ
# UCquPxkcyisPTMh4Zg_meHpQ
# UCi8e0iOVk1fEOogdfu4YgfA
# UC5sDJie6cAQ01G9D0mLMbzg
# UCpiLRBQAIDhzuxnDi9Oar4A
# UCLOi9fGe5EdPfquSe1RS5aA
# UCfF6arB_dR-Dpg4QGj6NhQA
# UCDJRFCKmzfISSFxO4lvCmag
# UCgjxQJ6TlKqhHax8742ZMdA
# UC60ldOm1QvY3sdO9YIThHUA
# UCalTcjVzL3ukTqsk5luyMxw
# UC1AJxP0vC_yqPUtr2MQttRQ
# UCpJN7kiUkDrH11p0GQhLyFw
# UCsEukrAd64fqA7FjwkmZ_Dw
# UC9v4vMSdJRND1YGp7-S8dRQ
# UCSkHYh2dxlQuzFYBD0NjJ1A
# UCXUu31gFmNRByr98i4YYQiQ
# UC3o1Qo_zRKv1G9c-vXHCDAg
# UCBgrughiR6sqygi_oqVdu2g
# UC9v4vMSdJRND1YGp7-S8dRQ
# UCN_u5w69V9wUZYG8WeJWuNg
# ...

# %% [markdown]
# # b ) Provide the following statistics for top 50 videos sorted by relevance in the US region

# %%
def get_video_id_by_url(url):
    """
    Return the Video ID from the video `url`
    """
    # split URL parts
    parsed_url = p.urlparse(url)
    # get the video ID by parsing the query of the URL
    video_id = p.parse_qs(parsed_url.query).get("v")
    if video_id:
        return video_id[0]
    else:
        raise Exception(f"Wasn't able to parse video URL: {url}")


def get_video_details(youtube, **kwargs):
    return youtube.videos().list(
        part="snippet,contentDetails,statistics",
        **kwargs
    ).execute()

def print_video_infos(video_response):
    items = video_response.get("items")[0]
    # get the snippet, statistics & content details from the video response
    snippet         = items["snippet"]
    id        = items["id"]
    statistics      = items["statistics"]
    content_details = items["contentDetails"]
    # get infos from the snippet
    channel_title = snippet["channelTitle"]
    title         = snippet["title"]
    description   = snippet["description"]
    publish_time  = snippet["publishedAt"]
    # get stats infos
    comment_count = statistics["commentCount"]
    like_count    = statistics["likeCount"]
    view_count    = statistics["viewCount"]
    id_list.append(id)
    title_list.append(title)
    likess_list.append(like_count)
    viewss_list.append(view_count)
    commentss_list.append(comment_count)
    # get duration from content details
    duration = content_details["duration"]
    # duration in the form of something like 'PT5H50M15S'
    # parsing it to be something like '5:50:15'
    # parsed_duration = re.search(f"PT(\d+H)?(\d+M)?(\d+S)", duration).groups()
    # duration_str = ""
    # for d in parsed_duration:
    #     if d:
    #         duration_str += f"{d[:-1]}:"
    # duration_str = duration_str.strip(":")
    print(f"""\
    Title: {title}
    Description: {description}
    Channel Title: {channel_title}
    Publish time: {publish_time}
    Number of comments: {comment_count}
    Number of likes: {like_count}
    Number of views: {view_count}
    """)

    return id_list, title_list, likess_list, viewss_list, commentss_list

# %% [markdown]
# # Write the csv file

# %%
# write a csv files with the columns id, description, likes, comments, views, channel title, video title
title = ['id', 'title', 'like_count', 'view_count', 'comment_count']
csv_file = open('youtube.csv', 'w', encoding='utf-8')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(title)
for i in range(len(video_ids)):
    print(i)
    video_url = "https://www.youtube.com/watch?v=" + video_ids[i]
    # parse video ID from URL
    video_id = get_video_id_by_url(video_url)
    # make API call to get video info
    response = get_video_details(youtube, id=video_id)
    # print extracted video infos
    id_list, title_list, likess_list, viewss_list, commentss_list = print_video_infos(response)
    print()
    try:
        csv_writer.writerow([video_ids[i], video_title[i], likess_list[i], viewss_list[i], commentss_list[i]])
    except IndexError as e:
        print(e)
        pass
csv_file.close()
# Out:
# 0
#     Title: Avatar: The Way of Water | New Hindi Trailer | December 16 in Cinemas | Advance Bookings Open Now
#     Description: 16 दिसंबर को, देखिए दुनिया की सबसे बड़ी फ़िल्म। देखिए #AvatarTheWayOfWater का नया ट्रेलर और फ़िल्म की टिकिट अभी बुक करें।
#
# Get tickets now:
# BMS: https://bookmy.show/Avatar
# Paytm: https://m.paytm.me/m_avatar2
#     Channel Title: 20th Century Studios India
#     Publish time: 2022-11-30T07:38:05Z
#     Number of comments: 83
#     Number of likes: 2003
#     Number of views: 15610
#
#
# 1
#     Title: Avatar: The Way of Water | New Telugu Trailer | December 16 in Cinemas | Advance Bookings Open Now
#     Description: డిసెంబర్ 16న, చలనచిత్ర చరిత్రలోనే ఓ అద్భుతాన్ని చూడడానికి సిద్ధం కండి. నేడే #AvatarTheWayOfWater సరికొత్త ట్రైలర్ చూడండి, వెంటనే టిక్కెట్లు బుక్ చేసుకోండి.
#
# Get tickets now:
# BMS: https://bookmy.show/Avatar
# Paytm: https://m.paytm.me/m_avatar2
#     Channel Title: 20th Century Studios India
# ...

# %% [markdown]
# # 3) Analyze the exported data and carry out the following tasks
# ### a) Sort the data by top comments in descending order and consider the video

# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('youtube.csv')

# %%
df.head()
# Out:
#             id                                              title  like_count  \
# 0  wcMqHWEJBgg  Avatar: The Way of Water | New Hindi Trailer |...        1255
# 1  B4oXYsJuH7o  Avatar: The Last Airbender S2 | Preview - Zuko...         348
# 2  Eae5XuaUa5k  പണ്ടോരയിൽ ഒരുനാൾ 🤣🤣🤣 @Karthik Surya @Village F...        1038
# 3  4winyNTfIJU  Sam Worthington Spills on Avatar: The Way of W...        1504
# 4  jJAVztgotE0  Zola’u nìprrte Neytiri (#ZoeSaldaña). #Avatar ...         552
#
#    view_count  comment_count
# 0        8402             61
# 1        4265              0
# 2        7151             99
# 3       31055            101
# 4        8212             11

# %%
# sort the dataframe using the view count
df = df.sort_values(by=['view_count'], ascending=False)

# %%
df.head()
# Out:
#              id                                              title  \
# 16  Vw85QmHD0wU  Drawing Aang from Avatar the Last Airbender in...
# 13  SutQj8w_3dc  Avatar 2 Banned In Kerala Explained | FEOUK vs...
# 3   4winyNTfIJU  Sam Worthington Spills on Avatar: The Way of W...
# 8   phkyAiDOjTw  Avatar 2 Needs $800 Million To Break Even (Not...
# 17  QykdSqPlpqM  She's so close | NEW FULL CLIP GMA | Jake & Ki...
#
#     like_count  view_count  comment_count
# 16       33037      176788            338
# 13        2805       38970            270
# 3         1504       31055            101
# 8          661       19965            225
# 17         321       12718             28

# %% [markdown]
# b)Write a program to loop through each video id, pass it to the suitable
# methods available in Reference tab (https://developers.google.com/youtube/v3/docs )
# Output expected : Use the python library “ pprint “ to print the output of the
# program with the following properties etag, items, id , kind snippet and p to have the
# text display field which represents the comment of videos

# %%
import json
import requests
import pprint

# get the API key from the config file
ids = df['id'].tolist()
api_key = DEVELOPER_KEY
# create a list to store the video data
video_data = []
count = 0
# loop through the video IDs
for video_id in ids:
    # create the API endpoint URL
    url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={video_id}&key={api_key}"
    # make the API request
    response = requests.get(url)
    # get the response data as JSON
    data = response.json()
    # get the snippet from the first item
    snippet = data['items'][0]['snippet']
    # get the title and description
    title = snippet['title']
    description = snippet['description']
    # get the channel title
    channel_title = snippet['channelTitle']
    # get the published at date
    published_at = snippet['publishedAt']
    # get the thumbnails
    thumbnails = snippet['thumbnails']
    # get the default thumbnail
    default_thumbnail = thumbnails['default']
    # get the default thumbnail url
    default_thumbnail_url = default_thumbnail['url']
    # get the high thumbnail
    high_thumbnail = thumbnails['high']
    # get the high thumbnail url
    high_thumbnail_url = high_thumbnail['url']
    # get the medium thumbnail
    medium_thumbnail = thumbnails['medium']
    # get the medium thumbnail url
    medium_thumbnail_url = medium_thumbnail['url']
    # create a dictionary of the video data
    video = {
        'video_id': video_id,
        'title': title,
        'description': description,
        'channel_title': channel_title,
        'tags': tags,
        'published_at': published_at,
        'default_thumbnail_url': default_thumbnail_url,
        'high_thumbnail_url': high_thumbnail_url,
        'medium_thumbnail_url': medium_thumbnail_url
    }
    count += 1
    # append the video data to the list
    video_data.append(video)
    # print the video data
    pprint.pprint(video_data)
    if count == 10:
        break
# Out:
# [{'channel_title': 'Scott Christian Sava',
#   'default_thumbnail_url': 'https://i.ytimg.com/vi/Vw85QmHD0wU/default.jpg',
#   'description': '#art #bensound #watercolor #alcoholmarkers #markers '
#                  '#coloredpencils #gouache #acrylicpainting '
#                  '#avatarthelastairbender #aang \n'
#                  '\n'
#                  'Artist, Dad, & Hobbit\n'
#                  'LIVE EVERY M/W/F AT 9AM CST \n'
#                  'ssavaart.com',
#   'high_thumbnail_url': 'https://i.ytimg.com/vi/Vw85QmHD0wU/hqdefault.jpg',
#   'medium_thumbnail_url': 'https://i.ytimg.com/vi/Vw85QmHD0wU/mqdefault.jpg',
#   'published_at': '2022-11-29T17:03:40Z',
#   'tags': ["avatar la via dell'acqua", 'avatar', 'victorlaszlo88'],
#   'title': 'Drawing Aang from Avatar the Last Airbender in 6 Different Mediums',
#   'video_id': 'Vw85QmHD0wU'}]
# [{'channel_title': 'Scott Christian Sava',
#   'default_thumbnail_url': 'https://i.ytimg.com/vi/Vw85QmHD0wU/default.jpg',
# ...

# %% [markdown]
# c) Write a program to export the output of question 3.b in JSON file format and
# submit the file as part of the assignment

# %%
with open('youtube.json', 'w') as f:
    json.dump(video_data, f, indent=4)

# %% [markdown]
# d) Write a function to get the likes vs views ratio of the top 10 videos with the
# highest comments

# %%
# Write a function to get the likes vs views ratio of the top 10 videos with the highest comments
def likes_vs_views_ratio(likes, views):
    return int(likes) / int(views)

for i in range(len(likess_list)):
    print(likes_vs_views_ratio(likess_list[i], viewss_list[i]))
# Out:
# 0.12831518257527227
# 0.10496037569709422
# 0.08826256258112368
# 0.07603821407681809
# 0.11584019273238305
# 0.04369381639880142
# 0.03667820069204152
# 0.021341463414634148
# 0.022344827586206897
# 0.056879739978331526
# 0.0325013380041843
# 0.07983512311530534
# 0.010610079575596816
# 0.07019435798142203
# 0.025292563231408077
# 0.10526315789473684
# 0.043795620437956206
# 0.18320614868825427
# 0.0988943488943489
# 0.024660059921640932
